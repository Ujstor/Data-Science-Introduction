# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# cleaned_data1 = pd.read_csv('cleaned_data1.csv')
# cleaned_data2 = pd.read_csv('cleaned_data2.csv')

# # Concatenate the two dataframes
# combined_data = pd.concat([cleaned_data1, cleaned_data2], ignore_index=True)

# # Write the combined dataframe to the final CSV file
# combined_data.to_csv('final_data.csv', index=False)

# %%
df = pd.read_csv(
    'final_data.csv', 
    parse_dates=['date'],)

# %%
df.head()
# Out:
#                   id       date  drive_time_min  pause_had_min  \
# 0  Stipan Aleksandar 2022-01-10             453             36
# 1  Stipan Aleksandar 2022-01-11             593             30
# 2  Stipan Aleksandar 2022-01-12             508             26
# 3  Stipan Aleksandar 2022-01-13             457             29
# 4  Stipan Aleksandar 2022-01-14             487             28
#
#    pause_should_min  total_time_hour
# 0                36         8.150000
# 1                45        10.633333
# 2                30         8.966667
# 3                30         8.116667
# 4                30         8.616667

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                468 non-null    object
#  1   date              468 non-null    datetime64[ns]
#  2   drive_time_min    468 non-null    int64
#  3   pause_had_min     468 non-null    int64
#  4   pause_should_min  468 non-null    int64
#  5   total_time_hour   468 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 22.1+ KB

# %%
df.describe()
# Out:
#                                 date  drive_time_min  pause_had_min  \
# count                            468      468.000000     468.000000
# mean   2022-05-09 06:55:23.076922880      493.128205      27.869658
# min              2021-05-01 00:00:00      298.000000       0.000000
# 25%              2021-10-05 18:00:00      464.000000      27.750000
# 50%              2022-04-05 12:00:00      481.000000      30.000000
# 75%              2022-12-08 06:00:00      518.000000      31.000000
# max              2023-06-30 00:00:00      705.000000      67.000000
# std                              NaN       46.982076       8.481628
#
#        pause_should_min  total_time_hour
# count        468.000000       468.000000
# mean          32.102564         8.753846
# min            0.000000         4.966667
# 25%           30.000000         8.250000
# 50%           30.000000         8.516667
# 75%           32.000000         9.150000
# max           67.000000        12.500000
# std            5.797636         0.851864

# %%
ax = df['total_time_hour'].plot(kind='density', figsize=(14, 6))
ax.axvline(df['total_time_hour'].mean(), color='red')
ax.axvline(df['total_time_hour'].median(), color='green')
ticks = np.arange(4, 13, 0.5)
ax.set_xticks(ticks)

detailed_ticks = np.arange(4, 13, 0.5)
ax.set_xticklabels(detailed_ticks)
plt.show()

# %%
df.plot(x='date', y='total_time_hour', figsize=(14, 6), fontsize=14, color='lightblue')
# Out:
# <Axes: xlabel='date'>

# %%
ax = df['total_time_hour'].plot(kind='hist', figsize=(14, 6), bins=60, fontsize=14, color='lightblue')
ax.set_ylabel('Days')
ax.set_xlabel('Working Hours')

ticks = np.arange(4, 13, 0.5)
ax.set_xticks(ticks)

detailed_ticks = np.arange(4, 13, 0.5)
ax.set_xticklabels(detailed_ticks)

plt.show()
