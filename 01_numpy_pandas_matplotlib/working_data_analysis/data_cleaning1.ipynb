# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv(
    'data/rawdata/combined_data1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1403 entries, 0 to 1402
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1385 non-null   object
#  1   Unnamed: 1   1357 non-null   object
#  2   Unnamed: 2   1357 non-null   object
#  3   Unnamed: 3   1337 non-null   object
#  4   Unnamed: 4   1356 non-null   object
#  5   Unnamed: 5   1375 non-null   object
#  6   Unnamed: 6   1337 non-null   object
#  7   Unnamed: 7   1374 non-null   object
#  8   Unnamed: 8   1356 non-null   object
#  9   Unnamed: 9   1375 non-null   object
#  10  Unnamed: 10  969 non-null    object
#  11  Unnamed: 11  20 non-null     object
#  12  Unnamed: 12  20 non-null     object
#  13  Unnamed: 13  20 non-null     object
#  14  Unnamed: 14  20 non-null     object
#  15  Unnamed: 15  20 non-null     object
#  16  Unnamed: 16  18 non-null     object
#  17  Unnamed: 17  18 non-null     object
# dtypes: object(18)
# memory usage: 197.4+ KB

# %%
df
# Out:
#                            Unnamed: 0           Unnamed: 1  \
# 0     Personal => Stipan Aleksandar                    NaN
# 1                            Personal          Ereignistag
# 2                   Stipan Aleksandar              01.2022
# 3                            Personal          Ereignistag
# 4                   Stipan Aleksandar  2022-01-10 00:00:00
# ...                               ...                  ...
# 1398                Stipan Aleksandar  2021-12-29 00:00:00
# 1399                Stipan Aleksandar  2021-12-30 00:00:00
# 1400                         Personal          Ereignistag
# 1401                         Personal          Ereignistag
# 1402                Stipan Aleksandar  2021-12-30 00:00:00
#
#                                          Unnamed: 2  \
# 0                                               NaN
# 1     Fahrerzeit <font size=\'1\'>(im Monat)</font>
# 2                                              8480
# 3                                       Fahrer Zeit
# 4                                               453
# ...                                             ...
# 1398                                         202522
# 1399                                            492
# 1400                                    Auftrag Nr.
# 1401                                    Auftrag Nr.
# 1402                                         202523
#
#                                     Unnamed: 3  \
# 0                                          NaN
# 1     Pause <font size=\'1\'>(im Monat)</font>
# 2                                          474
# 3                                        Pause
# 4                                           36
# ...                                        ...
# 1398                                  Hinfahrt
# 1399                                        30
# 1400                             Fahrtrichtung
# 1401                             Fahrtrichtung
# 1402                                  Hinfahrt
#
#                                              Unnamed: 4  \
# 0                                                   NaN
# 1     gesetzl. Pause <font size=\'1\'>(im Monat)</font>
# 2                                                   566
# 3                                        gesetzl. Pause
# 4                                                    36
# ...                                                 ...
# 1398                                   29.12.2021 07:28
# 1399                                                 30
# 1400                                     Beginn Auftrag
# 1401                                     Beginn Auftrag
# 1402                                   30.12.2021 07:26
#
#                                         Unnamed: 5 Unnamed: 6  \
# 0                                              NaN        NaN
# 1     Insgesamt <font size=\'1\'>(im Monat)</font>  Std. Lohn
# 2                                             7914          0
# 3                                        Insgesamt  Std. Lohn
# 4                                              417          0
# ...                                            ...        ...
# 1398                                         07:30         25
# 1399                                           462          0
# 1400                          Abholung/ Zustellung      Pause
# 1401                          Abholung/ Zustellung      Pause
# 1402                                         07:30         30
#
#                                              Unnamed: 7  \
# 0                                                   NaN
# 1     geleist. Bruttolohn <font size=\'1\'>(im Monat...
# 2                                                     0
# 3                                                  Lohn
# 4                                                     0
# ...                                                 ...
# 1398                                   29.12.2021 16:34
# 1399                                                  0
# 1400                                       Ende Auftrag
# 1401                                       Ende Auftrag
# 1402                                   30.12.2021 15:38
#
#                                        Unnamed: 8  \
# 0                                             NaN
# 1     Sollzeit <font size=\'1\'>(im Monat)</font>
# 2                                          124.61
# 3                                            Soll
# 4                                            7.33
# ...                                           ...
# 1398                                          521
# 1399                                         7.33
# 1400                       Auftragszeit Insgesamt
# 1401                       Auftragszeit Insgesamt
# 1402                                          462
#
#                                        Unnamed: 9  \
# 0                                             NaN
# 1     +- Diff. <font size=\'1\'>(im Monat)</font>
# 2                               7.290000000000006
# 3                                        +- Diff.
# 4                             -0.3799999999999999
# ...                                           ...
# 1398                                            0
# 1399                           0.3700000000000001
# 1400                                    Std. Lohn
# 1401                                    Std. Lohn
# 1402                                            0
#
#                                             Unnamed: 10           Unnamed: 11  \
# 0                                                   NaN                   NaN
# 1     mtl. Bruttolohn <font size=\'1\'>(lt. Arbeitsv...  +- Guthaben Vormonat
# 2                                                     0                     0
# 3                                                                         NaN
# 4                                                   NaN                   NaN
# ...                                                 ...                   ...
# 1398                                                  0                   NaN
# 1399                                                NaN                   NaN
# 1400                                               Lohn                   NaN
# 1401                                               Lohn                   NaN
# 1402                                                  0                   NaN
#
#                                             Unnamed: 12   Unnamed: 13  \
# 0                                                   NaN           NaN
# 1     geleist. Bruttolohn <font size=\'1\'>(im Monat...  Urlaub <br>5
# 2                                                     0             0
# 3                                                   NaN           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 1398                                                NaN           NaN
# 1399                                                NaN           NaN
# 1400                                                NaN           NaN
# 1401                                                NaN           NaN
# 1402                                                NaN           NaN
#
#       Unnamed: 14                                        Unnamed: 15  \
# 0             NaN                                                NaN
# 1     Krank <br>0  Insgesamt Bruttolohn <font size=\'1\'>(im Mona...
# 2               0                                                  0
# 3             NaN                                                NaN
# 4             NaN                                                NaN
# ...           ...                                                ...
# 1398          NaN                                                NaN
# 1399          NaN                                                NaN
# 1400          NaN                                                NaN
# 1401          NaN                                                NaN
# 1402          NaN                                                NaN
#
#           Unnamed: 16       Unnamed: 17
# 0                 NaN               NaN
# 1     Auszahlung Lohn  +- Rest-Guthaben
# 2                   0                 0
# 3                 NaN               NaN
# 4                 NaN               NaN
# ...               ...               ...
# 1398              NaN               NaN
# 1399              NaN               NaN
# 1400              NaN               NaN
# 1401              NaN               NaN
# 1402              NaN               NaN
#
# [1403 rows x 18 columns]

# %%
df.rename(columns={'Unnamed: 0': 'id', 'Unnamed: 1': 'date','Unnamed: 2': 'drive_time_min', 'Unnamed: 3': 'pause_had_min', 'Unnamed: 4': 'pause_should_min' }, inplace=True)

# %%
clean = df.loc[df['id'] == 'Stipan Aleksandar']

# %%
clean_columns = clean.drop(['Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'], axis=1)

# %%
clean_columns
# Out:
#                      id                 date drive_time_min pause_had_min  \
# 2     Stipan Aleksandar              01.2022           8480           474
# 4     Stipan Aleksandar  2022-01-10 00:00:00            453            36
# 7     Stipan Aleksandar  2022-01-10 00:00:00         202833      Hinfahrt
# 8     Stipan Aleksandar  2022-01-11 00:00:00            593            30
# 11    Stipan Aleksandar  2022-01-11 00:00:00         202834      Hinfahrt
# ...                 ...                  ...            ...           ...
# 1394  Stipan Aleksandar  2021-12-28 00:00:00         202521      Hinfahrt
# 1395  Stipan Aleksandar  2021-12-29 00:00:00            546            25
# 1398  Stipan Aleksandar  2021-12-29 00:00:00         202522      Hinfahrt
# 1399  Stipan Aleksandar  2021-12-30 00:00:00            492            30
# 1402  Stipan Aleksandar  2021-12-30 00:00:00         202523      Hinfahrt
#
#       pause_should_min
# 2                  566
# 4                   36
# 7     10.01.2022 07:53
# 8                   45
# 11    11.01.2022 07:26
# ...                ...
# 1394  28.12.2021 07:29
# 1395                30
# 1398  29.12.2021 07:28
# 1399                30
# 1402  30.12.2021 07:26
#
# [648 rows x 5 columns]

# %%
cleaned_rows.loc[:, 'date'] = pd.to_datetime(cleaned_rows['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
cleaned_rows = cleaned_rows.dropna(axis=0)
cleaned_rows = cleaned_rows.dropna(axis=1)
cleaned_rows = cleaned_rows.dropna(subset=['drive_time_min', 'pause_had_min', 'pause_should_min'])
cleaned_rows['drive_time_min'] = cleaned_rows['drive_time_min'].astype(int)
cleaned_rows['pause_had_min'] = cleaned_rows['pause_had_min'].astype(int)
cleaned_rows['pause_should_min'] = cleaned_rows['pause_should_min'].astype(int)

# %%
cleaned_rows
# Out:
#                      id       date  drive_time_min  pause_had_min  \
# 4     Stipan Aleksandar 2022-01-10             453             36
# 8     Stipan Aleksandar 2022-01-11             593             30
# 12    Stipan Aleksandar 2022-01-12             508             26
# 16    Stipan Aleksandar 2022-01-13             457             29
# 20    Stipan Aleksandar 2022-01-14             487             28
# ...                 ...        ...             ...            ...
# 1371  Stipan Aleksandar 2021-12-21             588             25
# 1375  Stipan Aleksandar 2021-12-22             474             23
# 1379  Stipan Aleksandar 2021-12-23             515             44
# 1395  Stipan Aleksandar 2021-12-29             546             25
# 1399  Stipan Aleksandar 2021-12-30             492             30
#
#       pause_should_min
# 4                   36
# 8                   45
# 12                  30
# 16                  30
# 20                  30
# ...                ...
# 1371                45
# 1375                30
# 1379                44
# 1395                30
# 1399                30
#
# [306 rows x 5 columns]

# %%
cleaned_rows['date'] = pd.to_datetime(cleaned_rows['date'], format='%Y-%m-%d')
cleaned_data = cleaned_rows

# %%
cleaned_data
# Out:
#                      id       date  drive_time_min  pause_had_min  \
# 4     Stipan Aleksandar 2022-01-10             453             36
# 8     Stipan Aleksandar 2022-01-11             593             30
# 12    Stipan Aleksandar 2022-01-12             508             26
# 16    Stipan Aleksandar 2022-01-13             457             29
# 20    Stipan Aleksandar 2022-01-14             487             28
# ...                 ...        ...             ...            ...
# 1371  Stipan Aleksandar 2021-12-21             588             25
# 1375  Stipan Aleksandar 2021-12-22             474             23
# 1379  Stipan Aleksandar 2021-12-23             515             44
# 1395  Stipan Aleksandar 2021-12-29             546             25
# 1399  Stipan Aleksandar 2021-12-30             492             30
#
#       pause_should_min
# 4                   36
# 8                   45
# 12                  30
# 16                  30
# 20                  30
# ...                ...
# 1371                45
# 1375                30
# 1379                44
# 1395                30
# 1399                30
#
# [306 rows x 5 columns]

# %%
cleaned_data['date'] = pd.to_datetime(cleaned_data['date'], format='%Y-%m-%d')

# %%
cleaned_data['total_time_hour'] = (cleaned_data['drive_time_min'] + cleaned_data['pause_should_min']) / 60

# %%
cleaned_data.describe()
# Out:
#                                 date  drive_time_min  pause_had_min  \
# count                            306      306.000000     306.000000
# mean   2021-12-11 13:05:52.941176576      500.650327      26.300654
# min              2021-05-01 00:00:00      298.000000       0.000000
# 25%              2021-08-12 06:00:00      470.000000      26.000000
# 50%              2021-12-01 12:00:00      488.000000      29.000000
# 75%              2022-03-29 18:00:00      531.000000      30.000000
# max              2022-08-31 00:00:00      705.000000      49.000000
# std                              NaN       51.288435       9.659165
#
#        pause_should_min  total_time_hour
# count        306.000000       306.000000
# mean          32.130719         8.879684
# min            0.000000         4.966667
# 25%           30.000000         8.333333
# 50%           30.000000         8.666667
# 75%           31.000000         9.350000
# max           49.000000        12.500000
# std            6.351138         0.936350

# %%
x = cleaned_data['total_time_hour'].plot(kind='hist', figsize=(14, 6), bins=20, fontsize=14, color='lightblue')

# %%
cleaned_data.plot(x='date', y='total_time_hour', figsize=(14, 6), fontsize=14, color='lightblue')
# Out:
# <Axes: xlabel='date'>

# %%
cleaned_data.to_csv('cleaned_data1.csv', index=False)
