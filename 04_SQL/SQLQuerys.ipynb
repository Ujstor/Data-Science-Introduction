# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
from getpass import getpass

password = getpass()

# %%
conn_str = "mysql+pymysql://root:{}@localhost:3306/ClassicModels".format(password)

# %%
# %sql $conn_str

# %%
# %sql show tables;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 8 rows affected.
# [('customers',),
#  ('employees',),
#  ('offices',),
#  ('orderdetails',),
#  ('orders',),
#  ('payments',),
#  ('productlines',),
#  ('products',)]

# %%
# %sql describe employees;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 8 rows affected.
# [('employeeNumber', 'int', 'NO', 'PRI', None, ''),
#  ('lastName', 'varchar(50)', 'NO', '', None, ''),
#  ('firstName', 'varchar(50)', 'NO', '', None, ''),
#  ('extension', 'varchar(10)', 'NO', '', None, ''),
#  ('email', 'varchar(100)', 'NO', '', None, ''),
#  ('reportsTo', 'int', 'YES', 'MUL', None, ''),
#  ('jobTitle', 'varchar(50)', 'NO', '', None, ''),
#  ('officeCode', 'varchar(10)', 'NO', 'MUL', None, '')]

# %% [markdown]
# ##### Expressions within a WHERE clause can be combined using AND and OR.
#
# SELECT column1, column2, ...<br>
# FROM table_name<br>
# WHERE condition1 AND condition2 AND condition3 ...;<br>
#
# The WHERE clause supports the following operators:
#
#     =
#     >
#     <
#     >=
#     <=
#     <> or !=
#     BETWEEN
#     LIKE
#     IN

# %%
# %sql select * from employees where jobTitle = 'Sales Rep';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 17 rows affected.
# [(1165, 'Jennings', 'Leslie', 'x3291', 'ljennings@classicmodelcars.com', 1143, 'Sales Rep', '1'),
#  (1166, 'Thompson', 'Leslie', 'x4065', 'lthompson@classicmodelcars.com', 1143, 'Sales Rep', '1'),
#  (1188, 'Firrelli', 'Julie', 'x2173', 'jfirrelli@classicmodelcars.com', 1143, 'Sales Rep', '2'),
#  (1216, 'Patterson', 'Steve', 'x4334', 'spatterson@classicmodelcars.com', 1143, 'Sales Rep', '2'),
#  (1286, 'Tseng', 'Foon Yue', 'x2248', 'ftseng@classicmodelcars.com', 1143, 'Sales Rep', '3'),
#  (1323, 'Vanauf', 'George', 'x4102', 'gvanauf@classicmodelcars.com', 1143, 'Sales Rep', '3'),
#  (1337, 'Bondur', 'Loui', 'x6493', 'lbondur@classicmodelcars.com', 1102, 'Sales Rep', '4'),
#  (1370, 'Hernandez', 'Gerard', 'x2028', 'ghernande@classicmodelcars.com', 1102, 'Sales Rep', '4'),
#  (1401, 'Castillo', 'Pamela', 'x2759', 'pcastillo@classicmodelcars.com', 1102, 'Sales Rep', '4'),
# ...

# %% [markdown]
# # Exercises

# %% [markdown]
# 1. Prepare a list of offices sorted by country, state, city.

# %%
# %sql select * from offices order by country, state, city;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 7 rows affected.
# [('6', 'Sydney', '+61 2 9264 2451', '5-11 Wentworth Avenue', 'Floor #2', 'NSW', 'Australia', '2010', 'APAC', b'\xe6\x10\x00\x00\x01\x01\x00\x00\x00m\x1a\xdbk\xc1\xe6b@\xe4\xbc\xff\x8f\x13\xee@\xc0'),
#  ('4', 'Paris', '+33 14 723 4404', "43 Rue Jouffroy D'abbans", None, None, 'France', '75017', 'EMEA', b'\xe6\x10\x00\x00\x01\x01\x00\x00\x00\xb8\x91\xb2E\xd2\xce\x02@\xfeG\xa6C\xa7mH@'),
#  ('5', 'Tokyo', '+81 33 224 5000', '4-1 Kioicho', None, 'Chiyoda-Ku', 'Japan', '102-8578', 'Japan', b'\xe6\x10\x00\x00\x01\x01\x00\x00\x00N\x0e\x9ft"va@\x02~\x8d$A\xd8A@'),
#  ('7', 'London', '+44 20 7877 2041', '25 Old Broad Street', 'Level 7', None, 'UK', 'EC2N 1HN', 'EMEA', b'\xe6\x10\x00\x00\x01\x01\x00\x00\x00/\xf7\xc9Q\x80(\xc0\xbf\xb6\x83\x11\xfb\x04\xc0I@'),
# ...

# %% [markdown]
# 2. How many employees are there in the company

# %%
# %sql select count(employeeNumber) from employees;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 1 rows affected.
# [(23,)]

# %% [markdown]
# 3. What is the total of payments received?

# %%
# %sql select round(sum(amount), 2) as totalPayments from payments;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 1 rows affected.
# [(8853839.23,)]

# %% [markdown]
# 4. List the product lines that contain 'Cars'.

# %%
# %sql select * from productlines where productLine like '%cars%';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 2 rows affected.
# [('Classic Cars', 'Attention car enthusiasts: Make your wildest car ownership dreams come true. Whether you are looking for classic muscle cars, dream sports cars or mo ... (437 characters truncated) ... cles. All models include a certificate of authenticity from their manufacturers and come fully assembled and ready for display in the home or office.', None, None),
#  ('Vintage Cars', 'Our Vintage Car models realistically portray automobiles produced from the early 1900s through the 1940s. Materials used include Bakelite, diecast, p ... (202 characters truncated) ... icas. All models include a certificate of authenticity from their manufacturers and come fully assembled and ready for display in the home or office.', None, None)]

# %% [markdown]
# 5. Report total payments for October 28, 2004.

# %%
# %sql select sum(amount) from payments where paymentDate='2004-10-28';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 1 rows affected.
# [(47411.33,)]

# %% [markdown]
# 6. Report those payments greater than \$100,000.

# %%
# %sql select * from payments where amount>=100000;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 5 rows affected.
# [('AE215433', datetime.datetime(2005, 3, 5, 0, 0), 101244.59, 124),
#  ('ID10962', datetime.datetime(2004, 12, 31, 0, 0), 116208.4, 141),
#  ('JE105477', datetime.datetime(2005, 3, 18, 0, 0), 120166.58, 141),
#  ('KI131716', datetime.datetime(2003, 8, 15, 0, 0), 111654.4, 124),
#  ('KM172879', datetime.datetime(2003, 12, 26, 0, 0), 105743.0, 148)]

# %% [markdown]
# 7. List the products in each product line.

# %%
# %%sql
#
# SELECT productLine, productName
# FROM products
# ORDER BY productLine, productName;

# %% [markdown]
# 8. How many products in each product line?

# %%
# %%sql
#
# SELECT ProductLine, COUNT(*) AS NumberOfProducts
# FROM Products
# GROUP BY ProductLine;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 7 rows affected.
# [('Classic Cars', 38),
#  ('Motorcycles', 13),
#  ('Planes', 12),
#  ('Ships', 9),
#  ('Trains', 3),
#  ('Trucks and Buses', 11),
#  ('Vintage Cars', 24)]

# %% [markdown]
# 9. What is the minimum payment received?

# %%
# %sql select min(amount) from payments;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 1 rows affected.
# [(615.45,)]

# %% [markdown]
# 10. List all payments greater than twice the average payment.

# %%
# %sql select * from payments where amount > 2 *( select avg(amount) from payments);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 13 rows affected.
# [('AE215433', datetime.datetime(2005, 3, 5, 0, 0), 101244.59, 124),
#  ('AL493079', datetime.datetime(2005, 5, 23, 0, 0), 75020.13, 323),
#  ('BG255406', datetime.datetime(2004, 8, 28, 0, 0), 85410.87, 124),
#  ('DJ15149', datetime.datetime(2003, 11, 3, 0, 0), 85559.12, 321),
#  ('ET64396', datetime.datetime(2005, 4, 16, 0, 0), 83598.04, 124),
#  ('GN228846', datetime.datetime(2003, 12, 3, 0, 0), 85024.46, 167),
#  ('ID10962', datetime.datetime(2004, 12, 31, 0, 0), 116208.4, 141),
#  ('IN446258', datetime.datetime(2005, 3, 25, 0, 0), 65071.26, 141),
#  ('JE105477', datetime.datetime(2005, 3, 18, 0, 0), 120166.58, 141),
#  ('KI131716', datetime.datetime(2003, 8, 15, 0, 0), 111654.4, 124),
#  ('KM172879', datetime.datetime(2003, 12, 26, 0, 0), 105743.0, 148),
#  ('MA765515', datetime.datetime(2004, 12, 15, 0, 0), 82261.22, 114),
#  ('NQ865547', datetime.datetime(2004, 3, 15, 0, 0), 80375.24, 239)]

# %% [markdown]
# 11. What is the average percentage markup of the MSRP on buyPrice?

# %%
# %sql select avg((MSRP - buyPrice)/buyPrice)*100 as AVGMarkupPrecentage from products;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 1 rows affected.
# [(88.70239217133998,)]

# %% [markdown]
# 12. How many distinct products does ClassicModels sell?

# %%
# %sql select COUNT(DISTINCT productCode) as NumberOfDistinctProducts from products;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 1 rows affected.
# [(110,)]

# %% [markdown]
# 13. Report the name and city of customers who don't have sales representatives?

# %%
# %sql select customerName, city from customers where salesRepEmployeeNumber is null;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 22 rows affected.
# [('Havel & Zbyszek Co', 'Warszawa'),
#  ('Porto Imports Co.', 'Lisboa'),
#  ('Asian Shopping Network, Co', 'Singapore'),
#  ('Nat', 'Cunewalde'),
#  ('ANG Resellers', 'Madrid'),
#  ('Messner Shopping Network', 'Frankfurt'),
#  ('Franken Gifts, Co', 'Manheim'),
#  ('BG&E Collectables', 'Fribourg'),
#  ('Schuyler Imports', 'Amsterdam'),
#  ('Der Hund Imports', 'Berlin'),
#  ('Cramer Spezialit', 'Brandenburg'),
#  ('Asian Treasures, Inc.', 'Cork'),
#  ('SAR Distributors, Co', 'Hatfield'),
#  ('Kommission Auto', 'Passau'),
#  ('Lisboa Souveniers, Inc', 'Lisboa'),
#  ('Stuttgart Collectable Exchange', 'Stuttgart'),
#  ('Feuer Online Stores, Inc', 'Leipzig'),
#  ('Warburg Exchange', 'Aachen'),
#  ('Anton Designs, Ltd.', 'Madrid'),
#  ('Mit Vergn', 'Mannheim'),
#  ('Kremlin Collectables, Co.', 'Saint Petersburg'),
#  ('Raanan Stores, Inc', 'Herzlia')]

# %% [markdown]
# 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.

# %%
# %%sql
#
# select CONCAT(firstName, ' ', lastName) as fullName
# from employees
# where jobTitle like '%VP%' or jobTitle like '%Manager%';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 5 rows affected.
# [('Mary Patterson',),
#  ('Jeff Firrelli',),
#  ('William Patterson',),
#  ('Gerard Bondur',),
#  ('Anthony Bow',)]

# %% [markdown]
# 15. Which orders have a value greater than $5,000?

# %%
# %sql select * from orderdetails where (quantityOrdered * priceEach) > 5000;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/ClassicModels
# 410 rows affected.
# [(10251, 'S10_1678', 59, 93.79, 2),
#  (10417, 'S10_1678', 66, 79.43, 2),
#  (10103, 'S10_1949', 26, 214.3, 11),
#  (10112, 'S10_1949', 29, 197.16, 1),
#  (10126, 'S10_1949', 38, 205.73, 11),
#  (10140, 'S10_1949', 37, 186.44, 11),
#  (10150, 'S10_1949', 45, 182.16, 8),
#  (10174, 'S10_1949', 34, 207.87, 4),
#  (10194, 'S10_1949', 42, 203.59, 11),
#  (10206, 'S10_1949', 47, 203.59, 6),
#  (10215, 'S10_1949', 35, 205.73, 3),
#  (10228, 'S10_1949', 29, 214.3, 2),
#  (10245, 'S10_1949', 34, 195.01, 9),
#  (10258, 'S10_1949', 32, 177.87, 6),
#  (10280, 'S10_1949', 34, 205.73, 2),
#  (10291, 'S10_1949', 37, 210.01, 11),
#  (10304, 'S10_1949', 47, 201.44, 6),
#  (10312, 'S10_1949', 48, 214.3, 3),
#  (10322, 'S10_1949', 40, 180.01, 1),
#  (10347, 'S10_1949', 30, 188.58, 1),
#  (10357, 'S10_1949', 32, 199.3, 10),
#  (10369, 'S10_1949', 41, 195.01, 2),
#  (10381, 'S10_1949', 36, 182.16, 3),
# ...
